# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = [8,9,1,2,3,4,5,6]
y = [1,2,6,7,4,3,9,8]

# %%
plt.scatter(x,y)
plt.show()

# %%
data =[1,2,4,5,6,7,8,9,2,5]

# %%
plt.hist(data,color='g')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
one=[1,2,3,4,5,6,7,8,9]
two=[2,3,6,2,5,7,8,1,9]
three=[6,2,7,9,1,5,3,4,0]

data= list([one,two,three])

# %%
plt.boxplot(data)
plt.show()

# %%
one=[1,2,3,4,5,6,7,8,9]
two=[2,3,6,2,5,7,8,1,9]
three=[6,2,7,9,1,5,3,4,0]

data= list([one,two,three])

# %%
plt.violinplot(data,showmedians=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fruit=('apple','mango','banana','watermelon')
quantity=[25,56,72,100]

# %%
plt.pie(quantity,labels=fruit)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(quantity,labels=fruit,autopct='%01f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fruit=('apple','mango','banana','watermelon')
quantity=[25,56,72,100]

# %%
plt.pie(quantity,labels=fruit,radius=2)
plt.pie([1],colors=['w'],radius=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
